# %% [markdown]
# <a href="https://colab.research.google.com/github/Vnykm/GN22CDBDS001_2113702/blob/main/2113702_NLP_PIPELINE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NLP - Pipeline

# %% [markdown]
# # Importing Libraries

# %%
# !pip install textacy
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: textacy in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.0.2)
# Requirement already satisfied: jellyfish>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (0.9.0)
# Requirement already satisfied: spacy>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (3.2.4)
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.63.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.21.5)
# Requirement already satisfied: cytoolz>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from textacy) (0.11.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.4.1)
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.2.4)
# Requirement already satisfied: pyphen>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (0.12.0)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.23.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.6.3)
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.1.0)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from cytoolz>=0.10.1->textacy) (0.11.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->textacy) (3.1.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.9.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.4.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (8.0.15)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.4.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.7)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.10.0.2)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (7.1.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0.0->textacy) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3.0.0->textacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0.0->textacy) (2.0.1)
# Collecting en-core-web-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.2.0/en_core_web_lg-3.2.0-py3-none-any.whl (777.4 MB)
#      |████████████████████████████████| 777.4 MB 5.3 kB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.2.0) (3.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.23.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.10.0.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.4.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.9.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (8.0.15)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.21.5)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (7.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
import textacy
from spacy import displacy

# %% [markdown]
# # Loading the Text file.
# # The text is taken from a Wikipedia Article.

# %%
# !wget https://raw.githubusercontent.com/Vnykm/GN22CDBDS001_2113702/main/text.txt

# %%
nlp= spacy.load('en_core_web_lg')
f = open('text.txt','rt') #Article about ASTERIA
data = f.read()
doc = nlp(data)
len(doc)
# Out:
# 551

# %% [markdown]
# # Step 1: Sentence Segmentation

# %%
for sen in list(doc.sents):
  print(sen)
# Out:
# ASTERIA (Arcsecond Space Telescope Enabling Research in Astrophysics) was a miniaturized space telescope technology demonstration and opportunistic science mission to conduct astrophysical measurements using a CubeSat.
# It was designed in collaboration between the Massachusetts Institute of Technology (MIT) and NASA's Jet Propulsion Laboratory.
# ASTERIA was the first JPL-built CubeSat to have been successfully operated in space.
# Originally envisioned as a project for training early career scientists and engineers, ASTERIA's technical goal was to achieve arcsecond-level line-of-sight pointing error and highly stable focal plane temperature control.
# These technologies are important for precision photometry, i.e., the measurement of stellar brightness over time.
# Precision photometry, in turn, provides a way to study stellar activity, transiting exoplanets, and other astrophysical phenomena.
#
# ASTERIA was launched on 14 August 2017 and deployed into low Earth orbit from the International Space Station on 20 November 2017.
# The primary mission lasted 90 days, but the satellite continued operations for 745 days through three extended missions until last successful communications were made on December 5, 2019.
# The satellite decayed 24 April 2020.
# The Principal Investigator was Canadian-American astronomer and planetary scientist Sara Seager, from the Massachusetts Institute of Technology.
#
# The Arcsecond Space Telescope Enabling Research in Astrophysics (ASTERIA) was a six-unit (6U) CubeSat space telescope deployed from the International Space Station (ISS) with the goal of testing new technologies for the detection of exoplanets using the transit method.
# The program was funded at JPL through the Phaeton Program for training early career employees.
# Its target mission lasted for 90 days, after which it was extended until the loss of contact with the spacecraft.
#
# ASTERIA's capabilities enabled precision photometry to be performed on an opportunistic basis to study stellar activity, transiting exoplanets, and other astrophysical phenomena.
# The technological objectives of the mission were "to achieve arcsecond-level line of sight pointing error, and highly stable focal plane temperature control for precision photometry" as a way to detect transiting exoplanets, and characterize their host stars.
# The pointing stability was demonstrated over 20-minute observations.
# Pointing repeatability would be determined over a minimum of five observations over eight or more days, with the target star being returned to the same position on the focal plane by adjusting the spacecraft orientation and focal plane position.
#
# This mission may serve as a pathfinder for a fleet of low-cost space telescopes observing multiple targets at once to refine long-term mission goals by identifying new objects for other telescopes to observe.
# The miniaturization of a photometric detection system into a CubeSat could enable a constellation of multiple orbiting observatories for a continuous study of the brightest Sun-like stars which is not possible by conventional space observatories given their cost.
# Having one or more CubeSats pointed at a target star for extended duration could reveal long-transiting exoplanets.
# This mission also provided additional information in the design of future space telescopes.

# %% [markdown]
# # Step 2: Word Tokenization

# %%
for token in doc:
  print((token.text, token.idx))
# Out:
# ('ASTERIA', 0)
# ('(', 8)
# ('Arcsecond', 9)
# ('Space', 19)
# ('Telescope', 25)
# ('Enabling', 35)
# ('Research', 44)
# ('in', 53)
# ('Astrophysics', 56)
# (')', 68)
# ('was', 70)
# ('a', 74)
# ('miniaturized', 76)
# ('space', 89)
# ('telescope', 95)
# ('technology', 105)
# ('demonstration', 116)
# ('and', 130)
# ('opportunistic', 134)
# ('science', 148)
# ('mission', 156)
# ('to', 164)
# ('conduct', 167)
# ('astrophysical', 175)
# ('measurements', 189)
# ('using', 202)
# ('a', 208)
# ('CubeSat', 210)
# ('.', 217)
# ('It', 219)
# ('was', 222)
# ('designed', 226)
# ('in', 235)
# ('collaboration', 238)
# ('between', 252)
# ('the', 260)
# ('Massachusetts', 264)
# ('Institute', 278)
# ('of', 288)
# ('Technology', 291)
# ('(', 302)
# ('MIT', 303)
# (')', 306)
# ('and', 308)
# ('NASA', 312)
# ("'s", 316)
# ('Jet', 319)
# ('Propulsion', 323)
# ('Laboratory', 334)
# ('.', 344)
# ('ASTERIA', 346)
# ('was', 354)
# ('the', 358)
# ('first', 362)
# ('JPL', 368)
# ('-', 371)
# ('built', 372)
# ('CubeSat', 378)
# ('to', 386)
# ('have', 389)
# ('been', 394)
# ('successfully', 399)
# ('operated', 412)
# ('in', 421)
# ('space', 424)
# ('.', 429)
# ('Originally', 431)
# ('envisioned', 442)
# ('as', 453)
# ('a', 456)
# ('project', 458)
# ('for', 466)
# ('training', 470)
# ('early', 479)
# ('career', 485)
# ('scientists', 492)
# ('and', 503)
# ('engineers', 507)
# (',', 516)
# ('ASTERIA', 518)
# ("'s", 525)
# ('technical', 528)
# ('goal', 538)
# ('was', 543)
# ('to', 547)
# ('achieve', 550)
# ('arcsecond', 558)
# ('-', 567)
# ('level', 568)
# ('line', 574)
# ('-', 578)
# ('of', 579)
# ('-', 581)
# ('sight', 582)
# ('pointing', 588)
# ('error', 597)
# ('and', 603)
# ('highly', 607)
# ('stable', 614)
# ('focal', 621)
# ('plane', 627)
# ('temperature', 633)
# ('control', 645)
# ('.', 652)
# ('These', 654)
# ('technologies', 660)
# ('are', 673)
# ('important', 677)
# ('for', 687)
# ('precision', 691)
# ('photometry', 701)
# (',', 711)
# ('i.e.', 713)
# (',', 717)
# ('the', 719)
# ('measurement', 723)
# ('of', 735)
# ('stellar', 738)
# ('brightness', 746)
# ('over', 757)
# ('time', 762)
# ('.', 766)
# ('Precision', 768)
# ('photometry', 778)
# (',', 788)
# ('in', 790)
# ('turn', 793)
# (',', 797)
# ('provides', 799)
# ('a', 808)
# ('way', 810)
# ('to', 814)
# ('study', 817)
# ('stellar', 823)
# ('activity', 831)
# (',', 839)
# ('transiting', 841)
# ('exoplanets', 852)
# (',', 862)
# ('and', 864)
# ('other', 868)
# ('astrophysical', 874)
# ('phenomena', 888)
# ('.', 897)
# ('\n', 898)
# ('ASTERIA', 899)
# ('was', 907)
# ('launched', 911)
# ('on', 920)
# ('14', 923)
# ('August', 926)
# ('2017', 933)
# ('and', 938)
# ('deployed', 942)
# ('into', 951)
# ('low', 956)
# ('Earth', 960)
# ('orbit', 966)
# ('from', 972)
# ('the', 977)
# ('International', 981)
# ('Space', 995)
# ('Station', 1001)
# ('on', 1009)
# ('20', 1012)
# ('November', 1015)
# ('2017', 1024)
# ('.', 1028)
# ('The', 1030)
# ('primary', 1034)
# ('mission', 1042)
# ('lasted', 1050)
# ('90', 1057)
# ('days', 1060)
# (',', 1064)
# ('but', 1066)
# ('the', 1070)
# ('satellite', 1074)
# ('continued', 1084)
# ('operations', 1094)
# ('for', 1105)
# ('745', 1109)
# ('days', 1113)
# ('through', 1118)
# ('three', 1126)
# ('extended', 1132)
# ('missions', 1141)
# ('until', 1150)
# ('last', 1156)
# ('successful', 1161)
# ('communications', 1172)
# ('were', 1187)
# ('made', 1192)
# ('on', 1197)
# ('December', 1200)
# ('5', 1209)
# (',', 1210)
# ('2019', 1212)
# ('.', 1216)
# ('The', 1218)
# ('satellite', 1222)
# ('decayed', 1232)
# ('24', 1240)
# ('April', 1243)
# ('2020', 1249)
# ('.', 1253)
# ('The', 1255)
# ('Principal', 1259)
# ('Investigator', 1269)
# ('was', 1282)
# ('Canadian', 1286)
# ('-', 1294)
# ('American', 1295)
# ('astronomer', 1304)
# ('and', 1315)
# ('planetary', 1319)
# ('scientist', 1329)
# ('Sara', 1339)
# ('Seager', 1344)
# (',', 1350)
# ('from', 1352)
# ('the', 1357)
# ('Massachusetts', 1361)
# ('Institute', 1375)
# ('of', 1385)
# ('Technology', 1388)
# ('.', 1398)
# ('\n', 1399)
# ('The', 1400)
# ('Arcsecond', 1404)
# ('Space', 1414)
# ('Telescope', 1420)
# ('Enabling', 1430)
# ('Research', 1439)
# ('in', 1448)
# ('Astrophysics', 1451)
# ('(', 1464)
# ('ASTERIA', 1465)
# (')', 1472)
# ('was', 1474)
# ('a', 1478)
# ('six', 1480)
# ('-', 1483)
# ('unit', 1484)
# ('(', 1489)
# ('6U', 1490)
# (')', 1492)
# ('CubeSat', 1494)
# ('space', 1502)
# ('telescope', 1508)
# ('deployed', 1518)
# ('from', 1527)
# ('the', 1532)
# ('International', 1536)
# ('Space', 1550)
# ('Station', 1556)
# ('(', 1564)
# ('ISS', 1565)
# (')', 1568)
# ('with', 1570)
# ('the', 1575)
# ('goal', 1579)
# ('of', 1584)
# ('testing', 1587)
# ('new', 1595)
# ('technologies', 1599)
# ('for', 1612)
# ('the', 1616)
# ('detection', 1620)
# ('of', 1630)
# ('exoplanets', 1633)
# ('using', 1644)
# ('the', 1650)
# ('transit', 1654)
# ('method', 1662)
# ('.', 1668)
# ('The', 1670)
# ('program', 1674)
# ('was', 1682)
# ('funded', 1686)
# ('at', 1693)
# ('JPL', 1696)
# ('through', 1700)
# ('the', 1708)
# ('Phaeton', 1712)
# ('Program', 1720)
# ('for', 1728)
# ('training', 1732)
# ('early', 1741)
# ('career', 1747)
# ('employees', 1754)
# ('.', 1763)
# ('Its', 1765)
# ('target', 1769)
# ('mission', 1776)
# ('lasted', 1784)
# ('for', 1791)
# ('90', 1795)
# ('days', 1798)
# (',', 1802)
# ('after', 1804)
# ('which', 1810)
# ('it', 1816)
# ('was', 1819)
# ('extended', 1823)
# ('until', 1832)
# ('the', 1838)
# ('loss', 1842)
# ('of', 1847)
# ('contact', 1850)
# ('with', 1858)
# ('the', 1863)
# ('spacecraft', 1867)
# ('.', 1877)
# ('\n', 1878)
# ('ASTERIA', 1879)
# ("'s", 1886)
# ('capabilities', 1889)
# ('enabled', 1902)
# ('precision', 1910)
# ('photometry', 1920)
# ('to', 1931)
# ('be', 1934)
# ('performed', 1937)
# ('on', 1947)
# ('an', 1950)
# ('opportunistic', 1953)
# ('basis', 1967)
# ('to', 1973)
# ('study', 1976)
# ('stellar', 1982)
# ('activity', 1990)
# (',', 1998)
# ('transiting', 2000)
# ('exoplanets', 2011)
# (',', 2021)
# ('and', 2023)
# ('other', 2027)
# ('astrophysical', 2033)
# ('phenomena', 2047)
# ('.', 2056)
# ('The', 2058)
# ('technological', 2062)
# ('objectives', 2076)
# ('of', 2087)
# ('the', 2090)
# ('mission', 2094)
# ('were', 2102)
# ('"', 2107)
# ('to', 2108)
# ('achieve', 2111)
# ('arcsecond', 2119)
# ('-', 2128)
# ('level', 2129)
# ('line', 2135)
# ('of', 2140)
# ('sight', 2143)
# ('pointing', 2149)
# ('error', 2158)
# (',', 2163)
# ('and', 2165)
# ('highly', 2169)
# ('stable', 2176)
# ('focal', 2183)
# ('plane', 2189)
# ('temperature', 2195)
# ('control', 2207)
# ('for', 2215)
# ('precision', 2219)
# ('photometry', 2229)
# ('"', 2239)
# ('as', 2241)
# ('a', 2244)
# ('way', 2246)
# ('to', 2250)
# ('detect', 2253)
# ('transiting', 2260)
# ('exoplanets', 2271)
# (',', 2281)
# ('and', 2283)
# ('characterize', 2287)
# ('their', 2300)
# ('host', 2306)
# ('stars', 2311)
# ('.', 2316)
# ('The', 2318)
# ('pointing', 2322)
# ('stability', 2331)
# ('was', 2341)
# ('demonstrated', 2345)
# ('over', 2358)
# ('20', 2363)
# ('-', 2365)
# ('minute', 2366)
# ('observations', 2373)
# ('.', 2385)
# ('Pointing', 2387)
# ('repeatability', 2396)
# ('would', 2410)
# ('be', 2416)
# ('determined', 2419)
# ('over', 2430)
# ('a', 2435)
# ('minimum', 2437)
# ('of', 2445)
# ('five', 2448)
# ('observations', 2453)
# ('over', 2466)
# ('eight', 2471)
# ('or', 2477)
# ('more', 2480)
# ('days', 2485)
# (',', 2489)
# ('with', 2491)
# ('the', 2496)
# ('target', 2500)
# ('star', 2507)
# ('being', 2512)
# ('returned', 2518)
# ('to', 2527)
# ('the', 2530)
# ('same', 2534)
# ('position', 2539)
# ('on', 2548)
# ('the', 2551)
# ('focal', 2555)
# ('plane', 2561)
# ('by', 2567)
# ('adjusting', 2570)
# ('the', 2580)
# ('spacecraft', 2584)
# ('orientation', 2595)
# ('and', 2607)
# ('focal', 2611)
# ('plane', 2617)
# ('position', 2623)
# ('.', 2631)
# ('\n', 2632)
# ('This', 2633)
# ('mission', 2638)
# ('may', 2646)
# ('serve', 2650)
# ('as', 2656)
# ('a', 2659)
# ('pathfinder', 2661)
# ('for', 2672)
# ('a', 2676)
# ('fleet', 2678)
# ('of', 2684)
# ('low', 2687)
# ('-', 2690)
# ('cost', 2691)
# ('space', 2696)
# ('telescopes', 2702)
# ('observing', 2713)
# ('multiple', 2723)
# ('targets', 2732)
# ('at', 2740)
# ('once', 2743)
# ('to', 2748)
# ('refine', 2751)
# ('long', 2758)
# ('-', 2762)
# ('term', 2763)
# ('mission', 2768)
# ('goals', 2776)
# ('by', 2782)
# ('identifying', 2785)
# ('new', 2797)
# ('objects', 2801)
# ('for', 2809)
# ('other', 2813)
# ('telescopes', 2819)
# ('to', 2830)
# ('observe', 2833)
# ('.', 2840)
# ('The', 2842)
# ('miniaturization', 2846)
# ('of', 2862)
# ('a', 2865)
# ('photometric', 2867)
# ('detection', 2879)
# ('system', 2889)
# ('into', 2896)
# ('a', 2901)
# ('CubeSat', 2903)
# ('could', 2911)
# ('enable', 2917)
# ('a', 2924)
# ('constellation', 2926)
# ('of', 2940)
# ('multiple', 2943)
# ('orbiting', 2952)
# ('observatories', 2961)
# ('for', 2975)
# ('a', 2979)
# ('continuous', 2981)
# ('study', 2992)
# ('of', 2998)
# ('the', 3001)
# ('brightest', 3005)
# ('Sun', 3015)
# ('-', 3018)
# ('like', 3019)
# ('stars', 3024)
# ('which', 3030)
# ('is', 3036)
# ('not', 3039)
# ('possible', 3043)
# ('by', 3052)
# ('conventional', 3055)
# ('space', 3068)
# ('observatories', 3074)
# ('given', 3088)
# ('their', 3094)
# ('cost', 3100)
# ('.', 3104)
# ('Having', 3106)
# ('one', 3113)
# ('or', 3117)
# ('more', 3120)
# ('CubeSats', 3125)
# ('pointed', 3134)
# ('at', 3142)
# ('a', 3145)
# ('target', 3147)
# ('star', 3154)
# ('for', 3159)
# ('extended', 3163)
# ('duration', 3172)
# ('could', 3181)
# ('reveal', 3187)
# ('long', 3194)
# ('-', 3198)
# ('transiting', 3199)
# ('exoplanets', 3210)
# ('.', 3220)
# ('This', 3222)
# ('mission', 3227)
# ('also', 3235)
# ('provided', 3240)
# ('additional', 3249)
# ('information', 3260)
# ('in', 3272)
# ('the', 3275)
# ('design', 3279)
# ('of', 3286)
# ('future', 3289)
# ('space', 3296)
# ('telescopes', 3302)
# ('.', 3312)

# %% [markdown]
# # Step 3: Predicting Parts of Speech for Each Token

# %%
for token in doc: 
  print(token, token.tag_, token.pos_, spacy.explain(token.tag_))
# Out:
# ASTERIA NNP PROPN noun, proper singular
# ( -LRB- PUNCT left round bracket
# Arcsecond NNP PROPN noun, proper singular
# Space NNP PROPN noun, proper singular
# Telescope NNP PROPN noun, proper singular
# Enabling NNP PROPN noun, proper singular
# Research NNP PROPN noun, proper singular
# in IN ADP conjunction, subordinating or preposition
# Astrophysics NNP PROPN noun, proper singular
# ) -RRB- PUNCT right round bracket
# was VBD AUX verb, past tense
# a DT DET determiner
# miniaturized VBN VERB verb, past participle
# space NN NOUN noun, singular or mass
# telescope NN NOUN noun, singular or mass
# technology NN NOUN noun, singular or mass
# demonstration NN NOUN noun, singular or mass
# and CC CCONJ conjunction, coordinating
# opportunistic JJ ADJ adjective (English), other noun-modifier (Chinese)
# science NN NOUN noun, singular or mass
# mission NN NOUN noun, singular or mass
# to TO PART infinitival "to"
# conduct VB VERB verb, base form
# astrophysical JJ ADJ adjective (English), other noun-modifier (Chinese)
# measurements NNS NOUN noun, plural
# using VBG VERB verb, gerund or present participle
# a DT DET determiner
# CubeSat NNP PROPN noun, proper singular
# . . PUNCT punctuation mark, sentence closer
# It PRP PRON pronoun, personal
# was VBD AUX verb, past tense
# designed VBN VERB verb, past participle
# in IN ADP conjunction, subordinating or preposition
# collaboration NN NOUN noun, singular or mass
# between IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# Massachusetts NNP PROPN noun, proper singular
# Institute NNP PROPN noun, proper singular
# of IN ADP conjunction, subordinating or preposition
# Technology NNP PROPN noun, proper singular
# ( -LRB- PUNCT left round bracket
# MIT NNP PROPN noun, proper singular
# ) -RRB- PUNCT right round bracket
# and CC CCONJ conjunction, coordinating
# NASA NNP PROPN noun, proper singular
# 's POS PART possessive ending
# Jet NNP PROPN noun, proper singular
# Propulsion NNP PROPN noun, proper singular
# Laboratory NNP PROPN noun, proper singular
# . . PUNCT punctuation mark, sentence closer
# ASTERIA NNP PROPN noun, proper singular
# was VBD AUX verb, past tense
# the DT DET determiner
# first JJ ADJ adjective (English), other noun-modifier (Chinese)
# JPL NNP PROPN noun, proper singular
# - HYPH PUNCT punctuation mark, hyphen
# built VBN VERB verb, past participle
# CubeSat NNP PROPN noun, proper singular
# to TO PART infinitival "to"
# have VB AUX verb, base form
# been VBN AUX verb, past participle
# successfully RB ADV adverb
# operated VBN VERB verb, past participle
# in IN ADP conjunction, subordinating or preposition
# space NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# Originally RB ADV adverb
# envisioned VBN VERB verb, past participle
# as IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# project NN NOUN noun, singular or mass
# for IN ADP conjunction, subordinating or preposition
# training VBG VERB verb, gerund or present participle
# early JJ ADJ adjective (English), other noun-modifier (Chinese)
# career NN NOUN noun, singular or mass
# scientists NNS NOUN noun, plural
# and CC CCONJ conjunction, coordinating
# engineers NNS NOUN noun, plural
# , , PUNCT punctuation mark, comma
# ASTERIA NNP PROPN noun, proper singular
# 's POS PART possessive ending
# technical JJ ADJ adjective (English), other noun-modifier (Chinese)
# goal NN NOUN noun, singular or mass
# was VBD AUX verb, past tense
# to TO PART infinitival "to"
# achieve VB VERB verb, base form
# arcsecond NN NOUN noun, singular or mass
# - HYPH PUNCT punctuation mark, hyphen
# level NN NOUN noun, singular or mass
# line NN NOUN noun, singular or mass
# - HYPH PUNCT punctuation mark, hyphen
# of IN ADP conjunction, subordinating or preposition
# - HYPH PUNCT punctuation mark, hyphen
# sight NN NOUN noun, singular or mass
# pointing NN NOUN noun, singular or mass
# error NN NOUN noun, singular or mass
# and CC CCONJ conjunction, coordinating
# highly RB ADV adverb
# stable JJ ADJ adjective (English), other noun-modifier (Chinese)
# focal JJ ADJ adjective (English), other noun-modifier (Chinese)
# plane NN NOUN noun, singular or mass
# temperature NN NOUN noun, singular or mass
# control NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# These DT DET determiner
# technologies NNS NOUN noun, plural
# are VBP AUX verb, non-3rd person singular present
# important JJ ADJ adjective (English), other noun-modifier (Chinese)
# for IN ADP conjunction, subordinating or preposition
# precision NN NOUN noun, singular or mass
# photometry NN NOUN noun, singular or mass
# , , PUNCT punctuation mark, comma
# i.e. FW X foreign word
# , , PUNCT punctuation mark, comma
# the DT DET determiner
# measurement NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# stellar JJ ADJ adjective (English), other noun-modifier (Chinese)
# brightness NN NOUN noun, singular or mass
# over IN ADP conjunction, subordinating or preposition
# time NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# Precision NN NOUN noun, singular or mass
# photometry NN NOUN noun, singular or mass
# , , PUNCT punctuation mark, comma
# in IN ADP conjunction, subordinating or preposition
# turn NN NOUN noun, singular or mass
# , , PUNCT punctuation mark, comma
# provides VBZ VERB verb, 3rd person singular present
# a DT DET determiner
# way NN NOUN noun, singular or mass
# to TO PART infinitival "to"
# study VB VERB verb, base form
# stellar JJ ADJ adjective (English), other noun-modifier (Chinese)
# activity NN NOUN noun, singular or mass
# , , PUNCT punctuation mark, comma
# transiting VBG VERB verb, gerund or present participle
# exoplanets NNS NOUN noun, plural
# , , PUNCT punctuation mark, comma
# and CC CCONJ conjunction, coordinating
# other JJ ADJ adjective (English), other noun-modifier (Chinese)
# astrophysical JJ ADJ adjective (English), other noun-modifier (Chinese)
# phenomena NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
#
#  _SP SPACE whitespace
# ASTERIA NNP PROPN noun, proper singular
# was VBD AUX verb, past tense
# launched VBN VERB verb, past participle
# on IN ADP conjunction, subordinating or preposition
# 14 CD NUM cardinal number
# August NNP PROPN noun, proper singular
# 2017 CD NUM cardinal number
# and CC CCONJ conjunction, coordinating
# deployed VBN VERB verb, past participle
# into IN ADP conjunction, subordinating or preposition
# low JJ ADJ adjective (English), other noun-modifier (Chinese)
# Earth NNP PROPN noun, proper singular
# orbit NN NOUN noun, singular or mass
# from IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# International NNP PROPN noun, proper singular
# Space NNP PROPN noun, proper singular
# Station NNP PROPN noun, proper singular
# on IN ADP conjunction, subordinating or preposition
# 20 CD NUM cardinal number
# November NNP PROPN noun, proper singular
# 2017 CD NUM cardinal number
# . . PUNCT punctuation mark, sentence closer
# The DT DET determiner
# primary JJ ADJ adjective (English), other noun-modifier (Chinese)
# mission NN NOUN noun, singular or mass
# lasted VBD VERB verb, past tense
# 90 CD NUM cardinal number
# days NNS NOUN noun, plural
# , , PUNCT punctuation mark, comma
# but CC CCONJ conjunction, coordinating
# the DT DET determiner
# satellite NN NOUN noun, singular or mass
# continued VBD VERB verb, past tense
# operations NNS NOUN noun, plural
# for IN ADP conjunction, subordinating or preposition
# 745 CD NUM cardinal number
# days NNS NOUN noun, plural
# through IN ADP conjunction, subordinating or preposition
# three CD NUM cardinal number
# extended JJ ADJ adjective (English), other noun-modifier (Chinese)
# missions NNS NOUN noun, plural
# until IN SCONJ conjunction, subordinating or preposition
# last JJ ADJ adjective (English), other noun-modifier (Chinese)
# successful JJ ADJ adjective (English), other noun-modifier (Chinese)
# communications NNS NOUN noun, plural
# were VBD AUX verb, past tense
# made VBN VERB verb, past participle
# on IN ADP conjunction, subordinating or preposition
# December NNP PROPN noun, proper singular
# 5 CD NUM cardinal number
# , , PUNCT punctuation mark, comma
# 2019 CD NUM cardinal number
# . . PUNCT punctuation mark, sentence closer
# The DT DET determiner
# satellite NN NOUN noun, singular or mass
# decayed VBD VERB verb, past tense
# 24 CD NUM cardinal number
# April NNP PROPN noun, proper singular
# 2020 CD NUM cardinal number
# . . PUNCT punctuation mark, sentence closer
# The DT DET determiner
# Principal NNP PROPN noun, proper singular
# Investigator NNP PROPN noun, proper singular
# was VBD AUX verb, past tense
# Canadian JJ ADJ adjective (English), other noun-modifier (Chinese)
# - HYPH PUNCT punctuation mark, hyphen
# American JJ ADJ adjective (English), other noun-modifier (Chinese)
# astronomer NN NOUN noun, singular or mass
# and CC CCONJ conjunction, coordinating
# planetary JJ ADJ adjective (English), other noun-modifier (Chinese)
# scientist NN NOUN noun, singular or mass
# Sara NNP PROPN noun, proper singular
# Seager NNP PROPN noun, proper singular
# , , PUNCT punctuation mark, comma
# from IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# Massachusetts NNP PROPN noun, proper singular
# Institute NNP PROPN noun, proper singular
# of IN ADP conjunction, subordinating or preposition
# Technology NNP PROPN noun, proper singular
# . . PUNCT punctuation mark, sentence closer
#
#  _SP SPACE whitespace
# The DT DET determiner
# Arcsecond NNP PROPN noun, proper singular
# Space NNP PROPN noun, proper singular
# Telescope NNP PROPN noun, proper singular
# Enabling NNP PROPN noun, proper singular
# Research NNP PROPN noun, proper singular
# in IN ADP conjunction, subordinating or preposition
# Astrophysics NNP PROPN noun, proper singular
# ( -LRB- PUNCT left round bracket
# ASTERIA NNP PROPN noun, proper singular
# ) -RRB- PUNCT right round bracket
# was VBD AUX verb, past tense
# a DT DET determiner
# six CD NUM cardinal number
# - HYPH PUNCT punctuation mark, hyphen
# unit NN NOUN noun, singular or mass
# ( -LRB- PUNCT left round bracket
# 6U NNP PROPN noun, proper singular
# ) -RRB- PUNCT right round bracket
# CubeSat NNP PROPN noun, proper singular
# space NN NOUN noun, singular or mass
# telescope NN NOUN noun, singular or mass
# deployed VBD VERB verb, past tense
# from IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# International NNP PROPN noun, proper singular
# Space NNP PROPN noun, proper singular
# Station NNP PROPN noun, proper singular
# ( -LRB- PUNCT left round bracket
# ISS NNP PROPN noun, proper singular
# ) -RRB- PUNCT right round bracket
# with IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# goal NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# testing VBG VERB verb, gerund or present participle
# new JJ ADJ adjective (English), other noun-modifier (Chinese)
# technologies NNS NOUN noun, plural
# for IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# detection NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# exoplanets NNS NOUN noun, plural
# using VBG VERB verb, gerund or present participle
# the DT DET determiner
# transit NN NOUN noun, singular or mass
# method NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# The DT DET determiner
# program NN NOUN noun, singular or mass
# was VBD AUX verb, past tense
# funded VBN VERB verb, past participle
# at IN ADP conjunction, subordinating or preposition
# JPL NNP PROPN noun, proper singular
# through IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# Phaeton NNP PROPN noun, proper singular
# Program NNP PROPN noun, proper singular
# for IN ADP conjunction, subordinating or preposition
# training VBG VERB verb, gerund or present participle
# early JJ ADJ adjective (English), other noun-modifier (Chinese)
# career NN NOUN noun, singular or mass
# employees NNS NOUN noun, plural
# . . PUNCT punctuation mark, sentence closer
# Its PRP$ PRON pronoun, possessive
# target NN NOUN noun, singular or mass
# mission NN NOUN noun, singular or mass
# lasted VBD VERB verb, past tense
# for IN ADP conjunction, subordinating or preposition
# 90 CD NUM cardinal number
# days NNS NOUN noun, plural
# , , PUNCT punctuation mark, comma
# after IN ADP conjunction, subordinating or preposition
# which WDT PRON wh-determiner
# it PRP PRON pronoun, personal
# was VBD AUX verb, past tense
# extended VBN VERB verb, past participle
# until IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# loss NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# contact NN NOUN noun, singular or mass
# with IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# spacecraft NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
#
#  _SP SPACE whitespace
# ASTERIA NNP PROPN noun, proper singular
# 's POS PART possessive ending
# capabilities NNS NOUN noun, plural
# enabled VBD VERB verb, past tense
# precision NN NOUN noun, singular or mass
# photometry NN NOUN noun, singular or mass
# to TO PART infinitival "to"
# be VB AUX verb, base form
# performed VBN VERB verb, past participle
# on IN ADP conjunction, subordinating or preposition
# an DT DET determiner
# opportunistic JJ ADJ adjective (English), other noun-modifier (Chinese)
# basis NN NOUN noun, singular or mass
# to TO PART infinitival "to"
# study VB VERB verb, base form
# stellar JJ ADJ adjective (English), other noun-modifier (Chinese)
# activity NN NOUN noun, singular or mass
# , , PUNCT punctuation mark, comma
# transiting VBG VERB verb, gerund or present participle
# exoplanets NNS NOUN noun, plural
# , , PUNCT punctuation mark, comma
# and CC CCONJ conjunction, coordinating
# other JJ ADJ adjective (English), other noun-modifier (Chinese)
# astrophysical JJ ADJ adjective (English), other noun-modifier (Chinese)
# phenomena NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# The DT DET determiner
# technological JJ ADJ adjective (English), other noun-modifier (Chinese)
# objectives NNS NOUN noun, plural
# of IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# mission NN NOUN noun, singular or mass
# were VBD AUX verb, past tense
# " `` PUNCT opening quotation mark
# to TO PART infinitival "to"
# achieve VB VERB verb, base form
# arcsecond NN NOUN noun, singular or mass
# - HYPH PUNCT punctuation mark, hyphen
# level NN NOUN noun, singular or mass
# line NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# sight NN NOUN noun, singular or mass
# pointing NN NOUN noun, singular or mass
# error NN NOUN noun, singular or mass
# , , PUNCT punctuation mark, comma
# and CC CCONJ conjunction, coordinating
# highly RB ADV adverb
# stable JJ ADJ adjective (English), other noun-modifier (Chinese)
# focal JJ ADJ adjective (English), other noun-modifier (Chinese)
# plane NN NOUN noun, singular or mass
# temperature NN NOUN noun, singular or mass
# control NN NOUN noun, singular or mass
# for IN ADP conjunction, subordinating or preposition
# precision NN NOUN noun, singular or mass
# photometry NN NOUN noun, singular or mass
# " '' PUNCT closing quotation mark
# as IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# way NN NOUN noun, singular or mass
# to TO PART infinitival "to"
# detect VB VERB verb, base form
# transiting VBG VERB verb, gerund or present participle
# exoplanets NNS NOUN noun, plural
# , , PUNCT punctuation mark, comma
# and CC CCONJ conjunction, coordinating
# characterize VB VERB verb, base form
# their PRP$ PRON pronoun, possessive
# host NN NOUN noun, singular or mass
# stars NNS NOUN noun, plural
# . . PUNCT punctuation mark, sentence closer
# The DT DET determiner
# pointing VBG VERB verb, gerund or present participle
# stability NN NOUN noun, singular or mass
# was VBD AUX verb, past tense
# demonstrated VBN VERB verb, past participle
# over IN ADP conjunction, subordinating or preposition
# 20 CD NUM cardinal number
# - HYPH PUNCT punctuation mark, hyphen
# minute NN NOUN noun, singular or mass
# observations NNS NOUN noun, plural
# . . PUNCT punctuation mark, sentence closer
# Pointing VBG VERB verb, gerund or present participle
# repeatability NN NOUN noun, singular or mass
# would MD AUX verb, modal auxiliary
# be VB AUX verb, base form
# determined VBN VERB verb, past participle
# over IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# minimum NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# five CD NUM cardinal number
# observations NNS NOUN noun, plural
# over IN ADP conjunction, subordinating or preposition
# eight CD NUM cardinal number
# or CC CCONJ conjunction, coordinating
# more JJR ADJ adjective, comparative
# days NNS NOUN noun, plural
# , , PUNCT punctuation mark, comma
# with IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# target NN NOUN noun, singular or mass
# star NN NOUN noun, singular or mass
# being VBG AUX verb, gerund or present participle
# returned VBN VERB verb, past participle
# to IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# same JJ ADJ adjective (English), other noun-modifier (Chinese)
# position NN NOUN noun, singular or mass
# on IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# focal JJ ADJ adjective (English), other noun-modifier (Chinese)
# plane NN NOUN noun, singular or mass
# by IN ADP conjunction, subordinating or preposition
# adjusting VBG VERB verb, gerund or present participle
# the DT DET determiner
# spacecraft NN NOUN noun, singular or mass
# orientation NN NOUN noun, singular or mass
# and CC CCONJ conjunction, coordinating
# focal JJ ADJ adjective (English), other noun-modifier (Chinese)
# plane NN NOUN noun, singular or mass
# position NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
#
#  _SP SPACE whitespace
# This DT DET determiner
# mission NN NOUN noun, singular or mass
# may MD AUX verb, modal auxiliary
# serve VB VERB verb, base form
# as IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# pathfinder NN NOUN noun, singular or mass
# for IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# fleet NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# low JJ ADJ adjective (English), other noun-modifier (Chinese)
# - HYPH PUNCT punctuation mark, hyphen
# cost NN NOUN noun, singular or mass
# space NN NOUN noun, singular or mass
# telescopes NNS NOUN noun, plural
# observing VBG VERB verb, gerund or present participle
# multiple JJ ADJ adjective (English), other noun-modifier (Chinese)
# targets NNS NOUN noun, plural
# at IN ADP conjunction, subordinating or preposition
# once RB ADV adverb
# to TO PART infinitival "to"
# refine VB VERB verb, base form
# long JJ ADJ adjective (English), other noun-modifier (Chinese)
# - HYPH PUNCT punctuation mark, hyphen
# term NN NOUN noun, singular or mass
# mission NN NOUN noun, singular or mass
# goals NNS NOUN noun, plural
# by IN ADP conjunction, subordinating or preposition
# identifying VBG VERB verb, gerund or present participle
# new JJ ADJ adjective (English), other noun-modifier (Chinese)
# objects NNS NOUN noun, plural
# for IN ADP conjunction, subordinating or preposition
# other JJ ADJ adjective (English), other noun-modifier (Chinese)
# telescopes NNS NOUN noun, plural
# to TO PART infinitival "to"
# observe VB VERB verb, base form
# . . PUNCT punctuation mark, sentence closer
# The DT DET determiner
# miniaturization NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# photometric JJ ADJ adjective (English), other noun-modifier (Chinese)
# detection NN NOUN noun, singular or mass
# system NN NOUN noun, singular or mass
# into IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# CubeSat NNP PROPN noun, proper singular
# could MD AUX verb, modal auxiliary
# enable VB VERB verb, base form
# a DT DET determiner
# constellation NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# multiple JJ ADJ adjective (English), other noun-modifier (Chinese)
# orbiting VBG VERB verb, gerund or present participle
# observatories NNS NOUN noun, plural
# for IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# continuous JJ ADJ adjective (English), other noun-modifier (Chinese)
# study NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# brightest JJS ADJ adjective, superlative
# Sun NNP PROPN noun, proper singular
# - HYPH PUNCT punctuation mark, hyphen
# like JJ ADJ adjective (English), other noun-modifier (Chinese)
# stars NNS NOUN noun, plural
# which WDT PRON wh-determiner
# is VBZ AUX verb, 3rd person singular present
# not RB PART adverb
# possible JJ ADJ adjective (English), other noun-modifier (Chinese)
# by IN ADP conjunction, subordinating or preposition
# conventional JJ ADJ adjective (English), other noun-modifier (Chinese)
# space NN NOUN noun, singular or mass
# observatories NNS NOUN noun, plural
# given VBN VERB verb, past participle
# their PRP$ PRON pronoun, possessive
# cost NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# Having VBG AUX verb, gerund or present participle
# one CD NUM cardinal number
# or CC CCONJ conjunction, coordinating
# more JJR ADJ adjective, comparative
# CubeSats NNPS PROPN noun, proper plural
# pointed VBD VERB verb, past tense
# at IN ADP conjunction, subordinating or preposition
# a DT DET determiner
# target NN NOUN noun, singular or mass
# star NN NOUN noun, singular or mass
# for IN ADP conjunction, subordinating or preposition
# extended JJ ADJ adjective (English), other noun-modifier (Chinese)
# duration NN NOUN noun, singular or mass
# could MD AUX verb, modal auxiliary
# reveal VB VERB verb, base form
# long RB ADV adverb
# - HYPH PUNCT punctuation mark, hyphen
# transiting VBG VERB verb, gerund or present participle
# exoplanets NNS NOUN noun, plural
# . . PUNCT punctuation mark, sentence closer
# This DT DET determiner
# mission NN NOUN noun, singular or mass
# also RB ADV adverb
# provided VBD VERB verb, past tense
# additional JJ ADJ adjective (English), other noun-modifier (Chinese)
# information NN NOUN noun, singular or mass
# in IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# design NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# future JJ ADJ adjective (English), other noun-modifier (Chinese)
# space NN NOUN noun, singular or mass
# telescopes NNS NOUN noun, plural
# . . PUNCT punctuation mark, sentence closer

# %% [markdown]
# # Step 4: Text Lemmatization

# %%
for token in doc: print(token, token.lemma_)
# Out:
# ASTERIA ASTERIA
# ( (
# Arcsecond Arcsecond
# Space Space
# Telescope Telescope
# Enabling Enabling
# Research Research
# in in
# Astrophysics Astrophysics
# ) )
# was be
# a a
# miniaturized miniaturize
# space space
# telescope telescope
# technology technology
# demonstration demonstration
# and and
# opportunistic opportunistic
# science science
# mission mission
# to to
# conduct conduct
# astrophysical astrophysical
# measurements measurement
# using use
# a a
# CubeSat CubeSat
# . .
# It it
# was be
# designed design
# in in
# collaboration collaboration
# between between
# the the
# Massachusetts Massachusetts
# Institute Institute
# of of
# Technology Technology
# ( (
# MIT MIT
# ) )
# and and
# NASA NASA
# 's 's
# Jet Jet
# Propulsion Propulsion
# Laboratory Laboratory
# . .
# ASTERIA ASTERIA
# was be
# the the
# first first
# JPL JPL
# - -
# built build
# CubeSat CubeSat
# to to
# have have
# been be
# successfully successfully
# operated operate
# in in
# space space
# . .
# Originally originally
# envisioned envision
# as as
# a a
# project project
# for for
# training train
# early early
# career career
# scientists scientist
# and and
# engineers engineer
# , ,
# ASTERIA ASTERIA
# 's 's
# technical technical
# goal goal
# was be
# to to
# achieve achieve
# arcsecond arcsecond
# - -
# level level
# line line
# - -
# of of
# - -
# sight sight
# pointing pointing
# error error
# and and
# highly highly
# stable stable
# focal focal
# plane plane
# temperature temperature
# control control
# . .
# These these
# technologies technology
# are be
# important important
# for for
# precision precision
# photometry photometry
# , ,
# i.e. i.e.
# , ,
# the the
# measurement measurement
# of of
# stellar stellar
# brightness brightness
# over over
# time time
# . .
# Precision precision
# photometry photometry
# , ,
# in in
# turn turn
# , ,
# provides provide
# a a
# way way
# to to
# study study
# stellar stellar
# activity activity
# , ,
# transiting transit
# exoplanets exoplanet
# , ,
# and and
# other other
# astrophysical astrophysical
# phenomena phenomena
# . .
#
#
#
# ASTERIA ASTERIA
# was be
# launched launch
# on on
# 14 14
# August August
# 2017 2017
# and and
# deployed deploy
# into into
# low low
# Earth Earth
# orbit orbit
# from from
# the the
# International International
# Space Space
# Station Station
# on on
# 20 20
# November November
# 2017 2017
# . .
# The the
# primary primary
# mission mission
# lasted last
# 90 90
# days day
# , ,
# but but
# the the
# satellite satellite
# continued continue
# operations operation
# for for
# 745 745
# days day
# through through
# three three
# extended extended
# missions mission
# until until
# last last
# successful successful
# communications communication
# were be
# made make
# on on
# December December
# 5 5
# , ,
# 2019 2019
# . .
# The the
# satellite satellite
# decayed decay
# 24 24
# April April
# 2020 2020
# . .
# The the
# Principal Principal
# Investigator Investigator
# was be
# Canadian canadian
# - -
# American american
# astronomer astronomer
# and and
# planetary planetary
# scientist scientist
# Sara Sara
# Seager Seager
# , ,
# from from
# the the
# Massachusetts Massachusetts
# Institute Institute
# of of
# Technology Technology
# . .
#
#
#
# The the
# Arcsecond Arcsecond
# Space Space
# Telescope Telescope
# Enabling Enabling
# Research Research
# in in
# Astrophysics Astrophysics
# ( (
# ASTERIA ASTERIA
# ) )
# was be
# a a
# six six
# - -
# unit unit
# ( (
# 6U 6U
# ) )
# CubeSat CubeSat
# space space
# telescope telescope
# deployed deploy
# from from
# the the
# International International
# Space Space
# Station Station
# ( (
# ISS ISS
# ) )
# with with
# the the
# goal goal
# of of
# testing test
# new new
# technologies technology
# for for
# the the
# detection detection
# of of
# exoplanets exoplanet
# using use
# the the
# transit transit
# method method
# . .
# The the
# program program
# was be
# funded fund
# at at
# JPL JPL
# through through
# the the
# Phaeton Phaeton
# Program Program
# for for
# training train
# early early
# career career
# employees employee
# . .
# Its its
# target target
# mission mission
# lasted last
# for for
# 90 90
# days day
# , ,
# after after
# which which
# it it
# was be
# extended extend
# until until
# the the
# loss loss
# of of
# contact contact
# with with
# the the
# spacecraft spacecraft
# . .
#
#
#
# ASTERIA ASTERIA
# 's 's
# capabilities capability
# enabled enable
# precision precision
# photometry photometry
# to to
# be be
# performed perform
# on on
# an an
# opportunistic opportunistic
# basis basis
# to to
# study study
# stellar stellar
# activity activity
# , ,
# transiting transit
# exoplanets exoplanet
# , ,
# and and
# other other
# astrophysical astrophysical
# phenomena phenomena
# . .
# The the
# technological technological
# objectives objective
# of of
# the the
# mission mission
# were be
# " "
# to to
# achieve achieve
# arcsecond arcsecond
# - -
# level level
# line line
# of of
# sight sight
# pointing pointing
# error error
# , ,
# and and
# highly highly
# stable stable
# focal focal
# plane plane
# temperature temperature
# control control
# for for
# precision precision
# photometry photometry
# " "
# as as
# a a
# way way
# to to
# detect detect
# transiting transit
# exoplanets exoplanet
# , ,
# and and
# characterize characterize
# their their
# host host
# stars star
# . .
# The the
# pointing point
# stability stability
# was be
# demonstrated demonstrate
# over over
# 20 20
# - -
# minute minute
# observations observation
# . .
# Pointing point
# repeatability repeatability
# would would
# be be
# determined determine
# over over
# a a
# minimum minimum
# of of
# five five
# observations observation
# over over
# eight eight
# or or
# more more
# days day
# , ,
# with with
# the the
# target target
# star star
# being be
# returned return
# to to
# the the
# same same
# position position
# on on
# the the
# focal focal
# plane plane
# by by
# adjusting adjust
# the the
# spacecraft spacecraft
# orientation orientation
# and and
# focal focal
# plane plane
# position position
# . .
#
#
#
# This this
# mission mission
# may may
# serve serve
# as as
# a a
# pathfinder pathfinder
# for for
# a a
# fleet fleet
# of of
# low low
# - -
# cost cost
# space space
# telescopes telescope
# observing observe
# multiple multiple
# targets target
# at at
# once once
# to to
# refine refine
# long long
# - -
# term term
# mission mission
# goals goal
# by by
# identifying identify
# new new
# objects object
# for for
# other other
# telescopes telescope
# to to
# observe observe
# . .
# The the
# miniaturization miniaturization
# of of
# a a
# photometric photometric
# detection detection
# system system
# into into
# a a
# CubeSat CubeSat
# could could
# enable enable
# a a
# constellation constellation
# of of
# multiple multiple
# orbiting orbit
# observatories observatory
# for for
# a a
# continuous continuous
# study study
# of of
# the the
# brightest bright
# Sun Sun
# - -
# like like
# stars star
# which which
# is be
# not not
# possible possible
# by by
# conventional conventional
# space space
# observatories observatory
# given give
# their their
# cost cost
# . .
# Having having
# one one
# or or
# more more
# CubeSats CubeSats
# pointed point
# at at
# a a
# target target
# star star
# for for
# extended extended
# duration duration
# could could
# reveal reveal
# long long
# - -
# transiting transit
# exoplanets exoplanet
# . .
# This this
# mission mission
# also also
# provided provide
# additional additional
# information information
# in in
# the the
# design design
# of of
# future future
# space space
# telescopes telescope
# . .

# %% [markdown]
# # Step 5: Identifying Stop Words

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
len(spacy_stopwords)
for stop_word in list(spacy_stopwords)[:10]: print(stop_word)
# Out:
# above
# several
# five
# seem
# whenever
# eight
# ourselves
# ’d
# me
# name

# %% [markdown]
# # Step 6: Dependency Parsing

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="046234b3fd014fb197e3a7212e9b358f-0" class="displacy" width="85800" height="1537.0" direction="ltr" style="max-width: none; height: 1537.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ASTERIA (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Arcsecond</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Space</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Telescope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Enabling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Research</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Astrophysics)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">miniaturized</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">space</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">telescope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">technology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">demonstration</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">opportunistic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">mission</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">conduct</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">astrophysical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">measurements</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">CubeSat.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">designed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-

# %% [markdown]
# # Step 6b: Finding Noun Phrases

# %%
chunkOfNouns = textacy.extract.noun_chunks(doc) 
allnounchunks = []
chunkOfNouns = map(str, chunkOfNouns) 
chunkOfNouns = map(str.lower, chunkOfNouns)
for chunk in chunkOfNouns:
  if len(chunk.split(' ')) > 1: 
    print(chunk)
    allnounchunks.append(chunk)
uniquenounchunks = set(allnounchunks)
uniquenounchunks
# Out:
# (arcsecond space telescope enabling research
# miniaturized space telescope technology demonstration
# opportunistic science mission
# astrophysical measurements
# massachusetts institute
# nasa's jet propulsion laboratory
# first jpl-built cubesat
# early career scientists
# asteria's technical goal
# highly stable focal plane temperature control
# precision photometry
# stellar brightness
# precision photometry
# stellar activity
# other astrophysical phenomena
# 14 august
# low earth orbit
# international space station
# 20 november
# primary mission
# 745 days
# three extended missions
# last successful communications
# principal investigator
# canadian-american astronomer
# planetary scientist
# sara seager
# massachusetts institute
# arcsecond space telescope enabling research
# international space station
# new technologies
# transit method
# phaeton program
# early career employees
# its target mission
# 90 days
# asteria's capabilities
# precision photometry
# opportunistic basis
# stellar activity
# other astrophysical phenomena
# technological objectives
# arcsecond-level line
# sight pointing error
# highly stable focal plane temperature control
# precision photometry
# their host stars
# pointing stability
# 20-minute observations
# five observations
# eight or more days
# target star
# same position
# focal plane
# spacecraft orientation
# focal plane position
# low-cost space telescopes
# multiple targets
# long-term mission goals
# new objects
# other telescopes
# photometric detection system
# multiple orbiting observatories
# continuous study
# brightest sun-like stars
# conventional space observatories
# their cost
# one or more cubesats
# target star
# extended duration
# long-transiting exoplanets
# additional information
# future space telescopes
# {'(arcsecond space telescope enabling research',
#  '14 august',
#  '20 november',
#  '20-minute observations',
#  '745 days',
#  '90 days',
#  'additional information',
#  'arcsecond space telescope enabling research',
#  'arcsecond-level line',
#  "asteria's capabilities",
#  "asteria's technical goal",
#  'astrophysical measurements',
#  'brightest sun-like stars',
#  'canadian-american astronomer',
#  'continuous study',
#  'conventional space observatories',
#  'early career employees',
#  'early career scientists',
#  'eight or more days',
#  'extended duration',
#  'first jpl-built cubesat',
#  'five observations',
#  'focal plane',
#  'focal plane position',
#  'future space telescopes',
#  'highly stable focal plane temperature control',
#  'international space station',
#  'its target mission',
#  'last successful communications',
#  'long-term mission goals',
#  'long-transiting exoplanets',
#  'low earth orbit',
#  'low-cost space telescopes',
#  'massachusetts institute',
#  'miniaturized space telescope technology demonstration',
#  'multiple orbiting observatories',
#  'multiple targets',
#  "nasa's jet propulsion laboratory",
#  'new objects',
#  'new technologies',
#  'one or more cubesats',
#  'opportunistic basis',
#  'opportunistic science mission',
#  'other astrophysical phenomena',
#  'other telescopes',
#  'phaeton program',
#  'photometric detection system',
#  'planetary scientist',
#  'pointing stability',
#  'precision photometry',
#  'primary mission',
#  'principal investigator',
#  'same position',
#  'sara seager',
#  'sight pointing error',
#  'spacecraft orientation',
#  'stellar activity',
#  'stellar brightness',
#  'target star',
#  'technological objectives',
#  'their cost',
#  'their host stars',
#  'three extended missions',
#  'transit method'}

# %% [markdown]
# # Step 7: Named Entity Recognition (NER)

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ASTERIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arcsecond Space Telescope Enabling Research in Astrophysics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# ) was a miniaturized space telescope technology demonstration and opportunistic science mission to conduct astrophysical measurements using a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CubeSat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . It was designed in collaboration between
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Massachusetts Institute of Technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MIT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NASA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jet Propulsion Laboratory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ASTERIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JPL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -built
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CubeSat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to have been successfully operated in space. Originally envisioned as a project for training early career scientists and engineers,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ASTERIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's technical goal was to achieve arcsecond-level line-of-sight pointing error and highly stable focal plane temperature control. These technologies are important for precision photometry, i.e., the measurement of stellar brightness over time. Precision photometry, in turn, provides a way to study stellar activity, transiting exoplanets, and other astrophysical phenomena.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ASTERIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was launched on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14 August 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and deployed into low
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  orbit from
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the International Space Station
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 November 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The primary mission lasted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but the satellite continued operations for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     745 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  through
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  extended missions until last successful communications were made on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 5, 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The satellite decayed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24 April 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The Principal Investigator was
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %% [markdown]
# # Step 8: Coreference Resolution

# %%
statements = textacy.extract.semistructured_statements(doc, entity="ASTERIA", cue='be')

print("Here are the things I know about ASTERIA:")

for statement in statements:
    subject, verb, fact = statement
    print(f" - {fact}")
# Out:
# Here are the things I know about ASTERIA:
#  - [a, miniaturized, space, telescope, technology, demonstration, and, opportunistic, science, mission, to, conduct, astrophysical, measurements, using, a, CubeSat]
#  - [the, first, JPL, -, built, CubeSat, to, have, been, successfully, operated, in, space]
